# %% [markdown]
# # full-inference-engine on Kaggle T4
#
# Before running: **Settings (right panel) -> Accelerator: GPU T4 x2**, **Internet: On**.
#
# Run the cells below in order. The last cell blocks on purpose to keep the VS Code
# tunnel and this session alive — leave it running while you work from VS Code.
# See `docs/kaggle-setup.md` in the repo for the full walkthrough.

# %%
# !nvidia-smi

# %%
# !git clone https://github.com/Vaibhav7711/full-inference-engine.git fol
# %cd fol

# %%
# !bash scripts/setup_kaggle.sh

# %%
# !python scripts/colab_preflight.py

# %%
# !bash scripts/kaggle_vscode_tunnel.sh
